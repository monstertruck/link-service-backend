# %%
import httpx
import json

BASE_URL = "http://localhost:8000"

def pretty(response: httpx.Response) -> None:
    print(f"Status: {response.status_code}")
    try:
        print(json.dumps(response.json(), indent=2))
    except Exception:
        print(response.text)

# %% [markdown]
# ## POST /links — submit a new URL (auto-summarize + categorize)

# %%
sample_link = "https://om.co/2026/05/15/ai-in-everything-everywhere/"

response = httpx.post(f"{BASE_URL}/links", json={
    "url": sample_link,
})
pretty(response)
# Out:
# Status: 201
# {
#   "id": 1,
#   "url": "https://om.co/2026/05/15/ai-in-everything-everywhere/",
#   "title": null,
#   "category": "tech",
#   "summary": "# Summary\n\nThe author argues that AI will fundamentally reshape internet architecture from the traditional client-server model toward a more distributed system where devices continuously communicate with each other and AI systems. Rather than a revolutionary peer-to-peer shift, this evolution will be incremental\u2014similar to how cloud computing abstracted but didn't replace the underlying client-server architecture. This distributed model requires new business models around billing, capacity, and ownership, as every device becomes both a consumer and producer of data, potentially disrupting current telecom and distribution industries.",
#   "status": "unread",
#   "status_changed_at": null
# }

# %%
response.__dict__
# Out:
# {'status_code': 201,
#  'headers': Headers({'date': 'Tue, 19 May 2026 13:04:38 GMT', 'server': 'uvicorn', 'content-length': '801', 'content-type': 'application/json'}),
#  '_request': <Request('POST', 'http://localhost:8000/links')>,
#  'next_request': None,
#  'extensions': {'http_version': b'HTTP/1.1',
#   'reason_phrase': b'Created',
#   'network_stream': <httpcore._backends.sync.SyncStream at 0x10b61fb50>},
#  'history': [],
#  'is_closed': True,
#  'is_stream_consumed': True,
#  'default_encoding': 'utf-8',
#  'stream': <httpx._client.BoundSyncStream at 0x10a9d8710>,
#  '_num_bytes_downloaded': 801,
#  '_decoder': <httpx._decoders.IdentityDecoder at 0x10b4dc790>,
#  '_elapsed': datetime.timedelta(seconds=3, microseconds=513203),
#  '_content': b'{"id":1,"url":"https://om.co/2026/05/15/ai-in-everything-everywhere/","title":null,"category":"tech","summary":"# Summary\\n\\nThe author argues that AI will fundamentally reshape internet architecture from the traditional client-server model toward a more distributed system where devices continuously communicate with each other and AI systems. Rather than a revolutionary peer-to-peer shift, this evolution will be incremental\xe2\x80\x94similar to how cloud computing abstracted but didn\'t replace the underlying client-server architecture. This distributed model requires new business models around billing, capacity, and ownership, as every device becomes both a consumer and producer of data, potentially disrupting current telecom and distribution industries.","status":"unread","status_changed_at":null}'}

# %% [markdown]
# ## POST /links — with a pre-supplied summary (skips Claude summarization)

# %%
response = httpx.post(f"{BASE_URL}/links", json={
    "url": "https://news.ycombinator.com",
    "title": "Hacker News",
    "summary": "Hacker News is a social news site focused on computer science and entrepreneurship.",
})
pretty(response)

# %% [markdown]
# ## POST /links — duplicate URL (should return 409 with existing record)

# %%
response = httpx.post(f"{BASE_URL}/links", json={
    "url": "https://news.ycombinator.com",
})
pretty(response)

# %% [markdown]
# ## GET /links — list all links

# %%
response = httpx.get(f"{BASE_URL}/links")
pretty(response)
# Out:
# Status: 200
# [
#   {
#     "id": 1,
#     "url": "https://om.co/2026/05/15/ai-in-everything-everywhere/",
#     "title": null,
#     "category": "tech",
#     "summary": "# Summary\n\nThe author argues that AI will fundamentally reshape internet architecture from the traditional client-server model toward a more distributed system where devices continuously communicate with each other and AI systems. Rather than a revolutionary peer-to-peer shift, this evolution will be incremental\u2014similar to how cloud computing abstracted but didn't replace the underlying client-server architecture. This distributed model requires new business models around billing, capacity, and ownership, as every device becomes both a consumer and producer of data, potentially disrupting current telecom and distribution industries.",
#     "status": "unread",
#     "status_changed_at": null
#   }
# ]

# %% [markdown]
# ## GET /links — filter by category

# %%
response = httpx.get(f"{BASE_URL}/links", params={"category": "tech"})
pretty(response)
# Out:
# Status: 200
# [
#   {
#     "id": 1,
#     "url": "https://om.co/2026/05/15/ai-in-everything-everywhere/",
#     "title": null,
#     "category": "tech",
#     "summary": "# Summary\n\nThe author argues that AI will fundamentally reshape internet architecture from the traditional client-server model toward a more distributed system where devices continuously communicate with each other and AI systems. Rather than a revolutionary peer-to-peer shift, this evolution will be incremental\u2014similar to how cloud computing abstracted but didn't replace the underlying client-server architecture. This distributed model requires new business models around billing, capacity, and ownership, as every device becomes both a consumer and producer of data, potentially disrupting current telecom and distribution industries.",
#     "status": "unread",
#     "status_changed_at": null
#   }
# ]

# %% [markdown]
# ## GET /links — filter by status

# %%
response = httpx.get(f"{BASE_URL}/links", params={"status": "unread"})
pretty(response)
# Out:
# Status: 200
# [
#   {
#     "id": 1,
#     "url": "https://om.co/2026/05/15/ai-in-everything-everywhere/",
#     "title": null,
#     "category": "tech",
#     "summary": "# Summary\n\nThe author argues that AI will fundamentally reshape internet architecture from the traditional client-server model toward a more distributed system where devices continuously communicate with each other and AI systems. Rather than a revolutionary peer-to-peer shift, this evolution will be incremental\u2014similar to how cloud computing abstracted but didn't replace the underlying client-server architecture. This distributed model requires new business models around billing, capacity, and ownership, as every device becomes both a consumer and producer of data, potentially disrupting current telecom and distribution industries.",
#     "status": "unread",
#     "status_changed_at": null
#   }
# ]

# %% [markdown]
# ## GET /links/{id} — fetch a single link

# %%
LINK_ID = 1  # change to a valid ID from above

response = httpx.get(f"{BASE_URL}/links/{LINK_ID}")
pretty(response)
# Out:
# Status: 200
# {
#   "id": 1,
#   "url": "https://om.co/2026/05/15/ai-in-everything-everywhere/",
#   "title": null,
#   "category": "tech",
#   "summary": "# Summary\n\nThe author argues that AI will fundamentally reshape internet architecture from the traditional client-server model toward a more distributed system where devices continuously communicate with each other and AI systems. Rather than a revolutionary peer-to-peer shift, this evolution will be incremental\u2014similar to how cloud computing abstracted but didn't replace the underlying client-server architecture. This distributed model requires new business models around billing, capacity, and ownership, as every device becomes both a consumer and producer of data, potentially disrupting current telecom and distribution industries.",
#   "status": "unread",
#   "status_changed_at": null
# }

# %% [markdown]
# ## PATCH /links/{id}/status — mark as read

# %%
response = httpx.patch(f"{BASE_URL}/links/{LINK_ID}/status", params={"status": "read"})
pretty(response)

# %% [markdown]
# ## GET /categories — all categories with link counts

# %%
response = httpx.get(f"{BASE_URL}/categories")
pretty(response)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/environments/usethis/lib/python3.11/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpcore/_sync/connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpcore/_sync/connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpcore/_backends/sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File ~/.pyenv/versions/3.11.13/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpcore/_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 response = httpx.get(f"{BASE_URL}/categories")
#       2 pretty(response)
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpx/_api.py:195, in get(url, params, headers, cookies, auth, proxy, follow_redirects, verify, timeout, trust_env)
#     174 def get(
#     175     url: URL | str,
#     176     *,
#    (...)    185     trust_env: bool = True,
#     186 ) -> Response:
#     187     """
#     188     Sends a `GET` request.
#     189
#    (...)    193     on this function, as `GET` requests should not include a request body.
#     194     """
# --> 195     return request(
#     196         "GET",
#     197         url,
#     198         params=params,
#     199         headers=headers,
#     200         cookies=cookies,
#     201         auth=auth,
#     202         proxy=proxy,
#     203         follow_redirects=follow_redirects,
#     204         verify=verify,
#     205         timeout=timeout,
#     206         trust_env=trust_env,
#     207     )
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpx/_api.py:109, in request(method, url, params, content, data, files, json, headers, cookies, auth, proxy, timeout, follow_redirects, verify, trust_env)
#      57 """
#      58 Sends an HTTP request.
#      59
#    (...)    100 ```
#     101 """
#     102 with Client(
#     103     cookies=cookies,
#     104     proxy=proxy,
#    (...)    107     trust_env=trust_env,
#     108 ) as client:
# --> 109     return client.request(
#     110         method=method,
#     111         url=url,
#     112         content=content,
#     113         data=data,
#     114         files=files,
#     115         json=json,
#     116         params=params,
#     117         headers=headers,
#     118         auth=auth,
#     119         follow_redirects=follow_redirects,
#     120     )
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpx/_client.py:825, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     810     warnings.warn(message, DeprecationWarning, stacklevel=2)
#     812 request = self.build_request(
#     813     method=method,
#     814     url=url,
#    (...)    823     extensions=extensions,
#     824 )
# --> 825 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     235 import httpcore
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/.pyenv/versions/3.11.13/lib/python3.11/contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     156     value = typ()
#     157 try:
# --> 158     self.gen.throw(typ, value, traceback)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#     163     return exc is not value
#
# File ~/environments/usethis/lib/python3.11/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     115     raise
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [Errno 61] Connection refused

# %% [markdown]
# ## DELETE /links/{id}

# %%
response = httpx.delete(f"{BASE_URL}/links/{LINK_ID}")
print(f"Status: {response.status_code}")  # 204 = deleted, 404 = not found
